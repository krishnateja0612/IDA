# %%
# !head breast-cancer.txt
# Out:
# recurrence-events	50-59	ge40	30-34	5-Mar	no	3	left	left_low	no

# %%
# !awk -- '{for(i=1;i<=NF;i++) wc[$i]+=1}; END {print length(wc)}' breast-cancer.txt
# Out:
# 54

# %%
# !wc -l breast-cancer.txt
# Out:
#        0 breast-cancer.txt

# %%
# !chmod u+x apriori.dms

# %%
# !./apriori.dms -ts -s-2 breast-cancer.txt T_AP_Freq_S2000.txt
# Out:
# /bin/sh: ./apriori.dms: cannot execute binary file
